# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student_exam_data.csv')

# %%
df.columns
# Out:
# Index(['Study Hours', 'Previous Exam Score', 'Pass/Fail'], dtype='object')

# %%
df = df.dropna()

# %%
df.isnull()
# Out:
#      Study Hours  Previous Exam Score  Pass/Fail
# 0          False                False      False
# 1          False                False      False
# 2          False                False      False
# 3          False                False      False
# 4          False                False      False
# ..           ...                  ...        ...
# 495        False                False      False
# 496        False                False      False
# 497        False                False      False
# 498        False                False      False
# 499        False                False      False
#
# [500 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Study Hours            0
# Previous Exam Score    0
# Pass/Fail              0
# dtype: int64

# %%
x = df[['Study Hours']]
y = df['Pass/Fail']

# %%
# Splitting the dataset into training and test set.  
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 1/3, random_state=0)

# %%
#Fitting the Simple Linear Regression model to the training dataset  
from sklearn.linear_model import LogisticRegression  
classifier = LogisticRegression()  
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 70.66%

# %%
plt.scatter(x_train, y_train, color="pink")
plt.plot(y_pred, x_test, color="green")
plt.show()

# %%
sns.regplot(x = x, y = y, data = df, logistic = True, ci = None, scatter_kws={'color': 'green'}, line_kws={'color': 'red'})
# Out:
# <Axes: xlabel='Study Hours', ylabel='Pass/Fail'>

# %%
x = df[['Previous Exam Score']]
y = df['Pass/Fail']

# %%
# Splitting the dataset into training and test set.  
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 1/3, random_state=0)

# %%
#Fitting the Simple Linear Regression model to the training dataset  
from sklearn.linear_model import LogisticRegression  
classifier = LogisticRegression()  
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 68.86%

# %%
sns.regplot(x = x, y = y, data = df, logistic = True, ci = None, scatter_kws={'color': 'green'}, line_kws={'color': 'red'})
# Out:
# <Axes: xlabel='Previous Exam Score', ylabel='Pass/Fail'>
